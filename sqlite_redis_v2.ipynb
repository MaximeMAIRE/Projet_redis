# %% [markdown]
# This version of the code focuses on trying to determine how the time taken for an insert, select, update or delete operation varies regarding the size of the query on an indexed database previously filled up with 1000 data.
#
# Authors: MAIRE Maxime & VLAYKOV Mathéo

# %%
import redis
import sqlite3
import pandas as pd
import numpy as np
from datetime import datetime
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
from os.path import exists

# %%
def create_sqlite_database(con_init, cur_init):
    """As the sqlite database will not be modified in this code, we create it only once and in this function.
        This sqlite database is an extract of the original mental_health.sqlite.

    Args:
        con_init (Connection): The connection to the original database
        cur_init (Cursor): The cursor to the original database
    """
    if not exists("mental_health_v2.sqlite"):
        con = sqlite3.connect("mental_health_v2.sqlite")
        cur = con.cursor()
        cur.execute("CREATE TABLE IF NOT EXISTS survey (SurveyID INTEGER, description TEXT);")
        cur.execute("CREATE TABLE IF NOT EXISTS question (questiontext TEXT, QuestionID INTEGER);")
        start_time = datetime.now().timestamp()
        cur.execute("CREATE TABLE IF NOT EXISTS answer (AnswerText TEXT, SurveyID INTEGER, UserID INTEGER, QuestionID INTEGER);")
        int = datetime.now().timestamp()
        con.commit()
        end = datetime.now().timestamp()
        print(int-start_time)
        print(end-int)
        

        res = cur_init.execute("SELECT * from survey ;")
        result = res.fetchall()
        res2 = cur_init.execute("SELECT * from question ;")
        result2 = res2.fetchall()
        res3 = cur_init.execute("SELECT * from answer LIMIT 1000;")
        result3 = res3.fetchall()

        for res in result:
            cur.execute("INSERT INTO survey (SurveyID, description) VALUES (?, ?)", res)

        for res in result2:
            cur.execute("INSERT INTO question (questiontext, QuestionID) VALUES (?, ?)", res)

        for res in result3:
            cur.execute("INSERT INTO answer (AnswerText, SurveyID, UserID, QuestionID) VALUES (?, ?, ?, ?)", res)

        con.commit()

# %%
def launch_all(nb_data):
    print("##################################################")
    print("OPERATIONS SUR",nb_data,"DONNEES ")
    print("##################################################\n\n")
    start_time = datetime.now().timestamp()
    r = redis.StrictRedis(host='localhost', port=6379, db=0)
    end_time = datetime.now().timestamp()
    print("Temps de connexion à la base de données redis:\n" + str(end_time - start_time) + " secondes.")

    ##################### IMPORT DES DONNEES #####################

    # Import des données sqlite dans redis
    start_time = datetime.now().timestamp()
    con_init = sqlite3.connect("mental_health.sqlite")
    end_time = datetime.now().timestamp()
    print("Temps de connexion à la base de données sqlite:\n" + str(end_time - start_time) + " secondes.")
    cur_init = con_init.cursor() 
    res = cur_init.execute("SELECT answer.SurveyID, survey.description, answer.QuestionID, question.questiontext, answer.AnswerText, answer.UserID from survey join answer on survey.SurveyId = answer.surveyId join question on question.QuestionID = answer.QuestionID LIMIT 1000")
    i = 0
    for row in res:
        r.set(str(i),str(row))
        i = i+1


    create_sqlite_database(con_init, cur_init)
    con_init.close()
    con = sqlite3.connect("mental_health_v2.sqlite")
    cur = con.cursor()
    

    #################################################
    ##################### REDIS #####################
    #################################################

    all_keys = []

    # Insertion de nb_data données dans redis
    insert_query = {}
    for i in range(1001, 1001+nb_data+1):
        # Utilisation d'une donnée existant réellement dans la base de données
        insert_query[i] = "(2016, 'mental health survey for 2016', 25, 'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?', 'None did', 2141)"
        all_keys.append(i)

    start_time = datetime.now().timestamp()
    r.mset(insert_query)
    end_time = datetime.now().timestamp()
    insert_redis = (end_time - start_time)

    # Récupération de nb_data données dans redis
    start_time = datetime.now().timestamp()
    r.mget(all_keys)
    end_time = datetime.now().timestamp()
    retrieval_redis = (end_time - start_time)


    update_query = {}
    for i in range(1001, 1001+nb_data+1):
        # Modification d'une donnée existant réellement dans la base de données
        update_query[i] = "(2016, 'mental health survey for 2016', 25, 'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?', 'None did', 2141)"
    
    start_time = datetime.now().timestamp()
    r.mset(update_query)
    end_time = datetime.now().timestamp()
    update_redis = (end_time - start_time)

    # Suppression de nb_data données dans redis
    start_time = datetime.now().timestamp()
    r.delete(*all_keys)
    end_time = datetime.now().timestamp()
    delete_redis = (end_time - start_time)

    ##################################################
    ##################### SQLITE #####################
    ##################################################
    
    # Insertion de nb_data données dans sqlite
    query_question = ""
    query_answer = ""
    for i in range(1001, 1001+nb_data+1):
        query_question += "INSERT INTO question (questiontext, QuestionID) VALUES ('Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?', '" + str(i) + "');"
        query_answer += "INSERT INTO answer (AnswerText, SurveyID, UserID, QuestionID) VALUES ('None did', 2016, 2141, '" + str(i) + "');"
    
    start_time = datetime.now().timestamp()
    cur.executescript(query_question)
    con.commit()
    intermediate_time = datetime.now().timestamp()
    cur.executescript(query_answer)
    con.commit()
    end_time = datetime.now().timestamp()
    first_insert_sqlite = (intermediate_time - start_time)
    second_insert_sqlite = (end_time - intermediate_time)
    total_insert_sqlite = (((intermediate_time - start_time)+(end_time - intermediate_time)))

    # Récupération de nb_data données dans sqlite
    query_retrieval = []
    for i in range(1001, 1001+nb_data+1):
        query_retrieval.append("SELECT answer.SurveyID, survey.description, answer.QuestionID, question.questiontext, answer.AnswerText, answer.UserID from survey join answer on survey.SurveyId = answer.surveyId join question on question.QuestionID = answer.QuestionID and answer.QuestionID = " + str(i) + ";")

    results = []
    retrieval_sqlite = 0
    for query in query_retrieval:
        start_time = datetime.now().timestamp()
        cur.execute(query)
        result = cur.fetchall()
        end_time = datetime.now().timestamp()
        results.append(result)
        retrieval_sqlite += (end_time - start_time)

    # Mise à jour de nb_data données dans sqlite
    query_update_question = ""
    query_update_answer = ""
    for i in range(1001, 1001+nb_data+1):
        query_update_question += "UPDATE question SET questiontext = 'Have you ever studied computer science?', QuestionID = " + str(1001+nb_data+i+1) + " WHERE questiontext = 'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?' and QuestionID = " + str(i) + ";"
        query_update_answer += "UPDATE answer SET SurveyID = 2015, QuestionID = "+ str(1001+nb_data+i+1) + " WHERE SurveyID = 2016 AND UserID = 2141 AND AnswerText = 'None did' AND QuestionID = " + str(i) + ";"
    
    start_time = datetime.now().timestamp()
    cur.executescript(query_update_question)
    con.commit()
    intermediate_time = datetime.now().timestamp()
    cur.executescript(query_update_answer)
    con.commit()
    end_time = datetime.now().timestamp()
    first_update_sqlite = (intermediate_time - start_time)
    second_update_sqlite = (end_time - intermediate_time)
    total_update_sqlite = (((intermediate_time - start_time)+(end_time - intermediate_time)))


    # Suppression de nb_data données dans sqlite
    query_delete_question = ""
    query_delete_answer = ""
    for i in range(1001, 1001+nb_data+1):
        query_delete_question += ("DELETE FROM question where QuestionID = " + str(1001+nb_data+i+1) + ";")
        query_delete_answer += ("DELETE FROM answer where QuestionID = " + str(1001+nb_data+i+1) + ";") 
    
    start_time = datetime.now().timestamp()
    cur.executescript(query_delete_question)
    con.commit()
    intermediate_time = datetime.now().timestamp()
    cur.executescript(query_delete_answer)
    con.commit()
    end_time = datetime.now().timestamp()
    first_delete_sqlite = (intermediate_time - start_time)
    second_delete_sqlite = (end_time - intermediate_time)
    total_delete_sqlite = (((intermediate_time - start_time)+(end_time - intermediate_time)))
    
    con.close()

    r.flushall()

    return [[insert_redis, retrieval_redis, update_redis, delete_redis], 
            [total_insert_sqlite, first_insert_sqlite, second_insert_sqlite, retrieval_sqlite,
            total_update_sqlite, first_update_sqlite, second_update_sqlite, total_delete_sqlite,
            first_delete_sqlite, second_delete_sqlite]]

# %%
def print_and_return_redis_perfs(performance, nb_data, i):
    """Print and return redis performance for an operation

    Args:
        performance (float): Time taken for the nb_data trial on one operation
        i (int): Describes the type of operation: 1 = insertion, 2 = retrieval, 3 = update, 4 (or else) = delete
    """

    operation = ""

    if i == 0:
        operation = "d'insertion"
    elif i==1:
        operation = "de récupération"
    elif i==2:
        operation = "de modification"
    else:
        operation = "de suppression"

    print(f"Temps {operation} de {nb_data} données sur une base de données préremplies 1000 données sur Redis:             {performance:.8f} s.")

# %%
def print_and_return_sqlite_perfs(total, first, second, nb_data, i):
    """Print and return SQLite mean and standard deviation for an operation

    Args:
        tab_total (float[]): Total time taken (= time taken on first and second table) for the nb_data trial on one operation
        tab_first (float[]): Time taken on the first table for the nb_data trial on one operation
        tab_second (float[]): Time taken on the second table for the nb_data trial on one operation
        i (int): Describes the type of operation: 1 = insertion, 2 = retrieval, 3 = update, 4 (or else) = delete
    """

    operation = ""
    new_line = ""
    if i == 0:
        operation = "d'insertion"
    elif i == 1:
        operation = "de modification"
    else:
        operation = "de suppression"
        new_line = "\n\n"

    print(f"Temps {operation} de {nb_data} données sur une base de données préremplies 1000 données sur SQLite:             {total:.8f} s.")
    print(f"Temps {operation} de {nb_data} données sur la 1ère table: {first:.8f} s.")
    print(f"Temps {operation} de {nb_data} données sur la 2ème table:  {second:.8f} s.{new_line}")

# %%
list_nb_data = [100, 500, 1000, 2500, 5000, 10000, 25000, 50000, 75000, 100000]

redis_insert = []
redis_retrieval = []
redis_update = []
redis_delete = []

sqlite_insert = []
sqlite_retrieval = []
sqlite_update = []
sqlite_delete = []

for data in list_nb_data:
    perfs = launch_all(data)
    redis_insert.append(perfs[0][0])
    redis_retrieval.append(perfs[0][1])
    redis_update.append(perfs[0][2])
    redis_delete.append(perfs[0][3])
    print_and_return_redis_perfs(perfs[0][0], data, 0)
    print_and_return_redis_perfs(perfs[0][1], data, 1)
    print_and_return_redis_perfs(perfs[0][2], data, 2)
    print_and_return_redis_perfs(perfs[0][3], data, 3)

    print_and_return_sqlite_perfs(perfs[1][0],perfs[1][1],perfs[1][2],data, 0)
    sqlite_insert.append(perfs[1][0])
    print(f"Temps de récupération en moyenne sur 1000 données sur SQLite:            {perfs[1][3]:.8f} s.")
    sqlite_retrieval.append(perfs[1][3])
    print_and_return_sqlite_perfs(perfs[1][4],perfs[1][5],perfs[1][6],data, 1)
    sqlite_update.append(perfs[1][4])
    print_and_return_sqlite_perfs(perfs[1][7],perfs[1][8],perfs[1][9], data, 2)
    sqlite_delete.append(perfs[1][7])
# Out:
# ##################################################
# OPERATIONS SUR 100 DONNEES
# ##################################################
#
#
# Temps de connexion à la base de données redis:
# 0.0002689361572265625 secondes.
# Temps de connexion à la base de données sqlite:
# 0.0011780261993408203 secondes.
# 0.0026938915252685547
# 1.4066696166992188e-05
# Temps d'insertion de 100 données sur une base de données préremplies 1000 données sur Redis:             0.00096989 s.
# Temps de récupération de 100 données sur une base de données préremplies 1000 données sur Redis:             0.00060320 s.
# Temps de modification de 100 données sur une base de données préremplies 1000 données sur Redis:             0.00064301 s.
# Temps de suppression de 100 données sur une base de données préremplies 1000 données sur Redis:             0.00026989 s.
# Temps d'insertion de 100 données sur une base de données préremplies 1000 données sur SQLite:             0.40067482 s.
# Temps d'insertion de 100 données sur la 1ère table: 0.20954490 s.
# Temps d'insertion de 100 données sur la 2ème table:  0.19112992 s.
# Temps de récupération en moyenne sur 1000 données sur SQLite:            0.02063251 s.
# Temps de modification de 100 données sur une base de données préremplies 1000 données sur SQLite:             0.40880704 s.
# Temps de modification de 100 données sur la 1ère table: 0.18948102 s.
# Temps de modification de 100 données sur la 2ème table:  0.21932602 s.
# Temps de suppression de 100 données sur une base de données préremplies 1000 données sur SQLite:             0.39702106 s.
# Temps de suppression de 100 données sur la 1ère table: 0.19366407 s.
# Temps de suppression de 100 données sur la 2ème table:  0.20335698 s.
#
#
# ##################################################
# OPERATIONS SUR 500 DONNEES
# ##################################################
#
#
# Temps de connexion à la base de données redis:
# 0.0001819133758544922 secondes.
# Temps de connexion à la base de données sqlite:
# 0.0002989768981933594 secondes.
# Temps d'insertion de 500 données sur une base de données préremplies 1000 données sur Redis:             0.00235510 s.
# Temps de récupération de 500 données sur une base de données préremplies 1000 données sur Redis:             0.00202394 s.
# Temps de modification de 500 données sur une base de données préremplies 1000 données sur Redis:             0.00220394 s.
# Temps de suppression de 500 données sur une base de données préremplies 1000 données sur Redis:             0.00095296 s.
# Temps d'insertion de 500 données sur une base de données préremplies 1000 données sur SQLite:             1.90081310 s.
# Temps d'insertion de 500 données sur la 1ère table: 0.94917393 s.
# Temps d'insertion de 500 données sur la 2ème table:  0.95163918 s.
# Temps de récupération en moyenne sur 1000 données sur SQLite:            0.13538289 s.
# Temps de modification de 500 données sur une base de données préremplies 1000 données sur SQLite:             2.10190701 s.
# Temps de modification de 500 données sur la 1ère table: 0.99686003 s.
# Temps de modification de 500 données sur la 2ème table:  1.10504699 s.
# Temps de suppression de 500 données sur une base de données préremplies 1000 données sur SQLite:             2.09365010 s.
# Temps de suppression de 500 données sur la 1ère table: 1.02637601 s.
# Temps de suppression de 500 données sur la 2ème table:  1.06727409 s.
#
#
# ##################################################
# OPERATIONS SUR 1000 DONNEES
# ##################################################
#
#
# Temps de connexion à la base de données redis:
# 0.00017881393432617188 secondes.
# Temps de connexion à la base de données sqlite:
# 0.0003139972686767578 secondes.
# Temps d'insertion de 1000 données sur une base de données préremplies 1000 données sur Redis:             0.00559211 s.
# Temps de récupération de 1000 données sur une base de données préremplies 1000 données sur Redis:             0.00453877 s.
# Temps de modification de 1000 données sur une base de données préremplies 1000 données sur Redis:             0.00458598 s.
# Temps de suppression de 1000 données sur une base de données préremplies 1000 données sur Redis:             0.00203395 s.
# Temps d'insertion de 1000 données sur une base de données préremplies 1000 données sur SQLite:             4.01749706 s.
# Temps d'insertion de 1000 données sur la 1ère table: 1.99235106 s.
# Temps d'insertion de 1000 données sur la 2ème table:  2.02514601 s.
# Temps de récupération en moyenne sur 1000 données sur SQLite:            0.35361791 s.
# Temps de modification de 1000 données sur une base de données préremplies 1000 données sur SQLite:             4.41583204 s.
# Temps de modification de 1000 données sur la 1ère table: 2.16981912 s.
# Temps de modification de 1000 données sur la 2ème table:  2.24601293 s.
# Temps de suppression de 1000 données sur une base de données préremplies 1000 données sur SQLite:             4.01756191 s.
# Temps de suppression de 1000 données sur la 1ère table: 1.96456289 s.
# Temps de suppression de 1000 données sur la 2ème table:  2.05299902 s.
#
#
# ##################################################
# OPERATIONS SUR 2500 DONNEES
# ##################################################
#
#
# Temps de connexion à la base de données redis:
# 0.0002589225769042969 secondes.
# Temps de connexion à la base de données sqlite:
# 0.0003998279571533203 secondes.
# Temps d'insertion de 2500 données sur une base de données préremplies 1000 données sur Redis:             0.01040077 s.
# Temps de récupération de 2500 données sur une base de données préremplies 1000 données sur Redis:             0.00976205 s.
# Temps de modification de 2500 données sur une base de données préremplies 1000 données sur Redis:             0.01027799 s.
# Temps de suppression de 2500 données sur une base de données préremplies 1000 données sur Redis:             0.00435996 s.
# Temps d'insertion de 2500 données sur une base de données préremplies 1000 données sur SQLite:             9.55760407 s.
# Temps d'insertion de 2500 données sur la 1ère table: 4.79719114 s.
# Temps d'insertion de 2500 données sur la 2ème table:  4.76041293 s.
# Temps de récupération en moyenne sur 1000 données sur SQLite:            1.52375841 s.
# Temps de modification de 2500 données sur une base de données préremplies 1000 données sur SQLite:             11.61524892 s.
# Temps de modification de 2500 données sur la 1ère table: 5.74316692 s.
# Temps de modification de 2500 données sur la 2ème table:  5.87208200 s.
# Temps de suppression de 2500 données sur une base de données préremplies 1000 données sur SQLite:             10.48599195 s.
# Temps de suppression de 2500 données sur la 1ère table: 5.09389901 s.
# Temps de suppression de 2500 données sur la 2ème table:  5.39209294 s.
#
#
# ##################################################
# OPERATIONS SUR 5000 DONNEES
# ##################################################
#
#
# Temps de connexion à la base de données redis:
# 0.0001659393310546875 secondes.
# Temps de connexion à la base de données sqlite:
# 0.0002560615539550781 secondes.
# Temps d'insertion de 5000 données sur une base de données préremplies 1000 données sur Redis:             0.02403808 s.
# Temps de récupération de 5000 données sur une base de données préremplies 1000 données sur Redis:             0.02317595 s.
# Temps de modification de 5000 données sur une base de données préremplies 1000 données sur Redis:             0.02236104 s.
# Temps de suppression de 5000 données sur une base de données préremplies 1000 données sur Redis:             0.01081991 s.
# Temps d'insertion de 5000 données sur une base de données préremplies 1000 données sur SQLite:             19.25611711 s.
# Temps d'insertion de 5000 données sur la 1ère table: 9.72800708 s.
# Temps d'insertion de 5000 données sur la 2ème table:  9.52811003 s.
# Temps de récupération en moyenne sur 1000 données sur SQLite:            5.31415868 s.
# Temps de modification de 5000 données sur une base de données préremplies 1000 données sur SQLite:             26.97569799 s.
# Temps de modification de 5000 données sur la 1ère table: 13.13490605 s.
# Temps de modification de 5000 données sur la 2ème table:  13.84079194 s.
# Temps de suppression de 5000 données sur une base de données préremplies 1000 données sur SQLite:             20.38385510 s.
# Temps de suppression de 5000 données sur la 1ère table: 10.12144613 s.
# Temps de suppression de 5000 données sur la 2ème table:  10.26240897 s.
#
#
# ##################################################
# OPERATIONS SUR 10000 DONNEES
# ##################################################
#
#
# Temps de connexion à la base de données redis:
# 0.00027298927307128906 secondes.
# Temps de connexion à la base de données sqlite:
# 0.0003628730773925781 secondes.
# Temps d'insertion de 10000 données sur une base de données préremplies 1000 données sur Redis:             0.04870009 s.
# Temps de récupération de 10000 données sur une base de données préremplies 1000 données sur Redis:             0.04494119 s.
# Temps de modification de 10000 données sur une base de données préremplies 1000 données sur Redis:             0.04387307 s.
# Temps de suppression de 10000 données sur une base de données préremplies 1000 données sur Redis:             0.01971197 s.
# Temps d'insertion de 10000 données sur une base de données préremplies 1000 données sur SQLite:             35.62026620 s.
# Temps d'insertion de 10000 données sur la 1ère table: 17.86211419 s.
# Temps d'insertion de 10000 données sur la 2ème table:  17.75815201 s.
# Temps de récupération en moyenne sur 1000 données sur SQLite:            15.66051769 s.
# Temps de modification de 10000 données sur une base de données préremplies 1000 données sur SQLite:             69.01495600 s.
# Temps de modification de 10000 données sur la 1ère table: 31.84194589 s.
# Temps de modification de 10000 données sur la 2ème table:  37.17301011 s.
# Temps de suppression de 10000 données sur une base de données préremplies 1000 données sur SQLite:             228.83855700 s.
# Temps de suppression de 10000 données sur la 1ère table: 102.65347695 s.
# Temps de suppression de 10000 données sur la 2ème table:  126.18508005 s.
#
#
# ##################################################
# OPERATIONS SUR 25000 DONNEES
# ##################################################
#
#
# Temps de connexion à la base de données redis:
# 0.00020313262939453125 secondes.
# Temps de connexion à la base de données sqlite:
# 0.0004379749298095703 secondes.
# Temps d'insertion de 25000 données sur une base de données préremplies 1000 données sur Redis:             0.12821388 s.
# Temps de récupération de 25000 données sur une base de données préremplies 1000 données sur Redis:             0.12418604 s.
# Temps de modification de 25000 données sur une base de données préremplies 1000 données sur Redis:             0.10947585 s.
# Temps de suppression de 25000 données sur une base de données préremplies 1000 données sur Redis:             0.04451013 s.
# Temps d'insertion de 25000 données sur une base de données préremplies 1000 données sur SQLite:             93.36564708 s.
# Temps d'insertion de 25000 données sur la 1ère table: 49.08409500 s.
# Temps d'insertion de 25000 données sur la 2ème table:  44.28155208 s.
# Temps de récupération en moyenne sur 1000 données sur SQLite:            102.70980763 s.
# Temps de modification de 25000 données sur une base de données préremplies 1000 données sur SQLite:             309.84567308 s.
# Temps de modification de 25000 données sur la 1ère table: 174.38242388 s.
# Temps de modification de 25000 données sur la 2ème table:  135.46324921 s.
# Temps de suppression de 25000 données sur une base de données préremplies 1000 données sur SQLite:             160.13439107 s.
# Temps de suppression de 25000 données sur la 1ère table: 85.92792606 s.
# Temps de suppression de 25000 données sur la 2ème table:  74.20646501 s.
#
#
# ##################################################
# OPERATIONS SUR 50000 DONNEES
# ##################################################
#
#
# Temps de connexion à la base de données redis:
# 0.00026798248291015625 secondes.
# Temps de connexion à la base de données sqlite:
# 0.0004451274871826172 secondes.
# Temps d'insertion de 50000 données sur une base de données préremplies 1000 données sur Redis:             0.23972797 s.
# Temps de récupération de 50000 données sur une base de données préremplies 1000 données sur Redis:             0.20142698 s.
# Temps de modification de 50000 données sur une base de données préremplies 1000 données sur Redis:             0.21439099 s.
# Temps de suppression de 50000 données sur une base de données préremplies 1000 données sur Redis:             0.10276580 s.
# Temps d'insertion de 50000 données sur une base de données préremplies 1000 données sur SQLite:             178.84574890 s.
# Temps d'insertion de 50000 données sur la 1ère table: 89.01429486 s.
# Temps d'insertion de 50000 données sur la 2ème table:  89.83145404 s.
# Temps de récupération en moyenne sur 1000 données sur SQLite:            397.94207096 s.
# Temps de modification de 50000 données sur une base de données préremplies 1000 données sur SQLite:             1007.92309093 s.
# Temps de modification de 50000 données sur la 1ère table: 566.83319807 s.
# Temps de modification de 50000 données sur la 2ème table:  441.08989286 s.
# Temps de suppression de 50000 données sur une base de données préremplies 1000 données sur SQLite:             497.46280003 s.
# Temps de suppression de 50000 données sur la 1ère table: 292.70416188 s.
# Temps de suppression de 50000 données sur la 2ème table:  204.75863814 s.
#
#
# ##################################################
# OPERATIONS SUR 75000 DONNEES
# ##################################################
#
#
# Temps de connexion à la base de données redis:
# 0.0001659393310546875 secondes.
# Temps de connexion à la base de données sqlite:
# 0.0002589225769042969 secondes.
# Temps d'insertion de 75000 données sur une base de données préremplies 1000 données sur Redis:             0.33592510 s.
# Temps de récupération de 75000 données sur une base de données préremplies 1000 données sur Redis:             0.32384300 s.
# Temps de modification de 75000 données sur une base de données préremplies 1000 données sur Redis:             0.30355191 s.
# Temps de suppression de 75000 données sur une base de données préremplies 1000 données sur Redis:             0.13901687 s.
# Temps d'insertion de 75000 données sur une base de données préremplies 1000 données sur SQLite:             268.61234903 s.
# Temps d'insertion de 75000 données sur la 1ère table: 135.05484486 s.
# Temps d'insertion de 75000 données sur la 2ème table:  133.55750418 s.
# Temps de récupération en moyenne sur 1000 données sur SQLite:            885.60516286 s.
# Temps de modification de 75000 données sur une base de données préremplies 1000 données sur SQLite:             2107.76200294 s.
# Temps de modification de 75000 données sur la 1ère table: 1148.27606702 s.
# Temps de modification de 75000 données sur la 2ème table:  959.48593593 s.
# Temps de suppression de 75000 données sur une base de données préremplies 1000 données sur SQLite:             912.31866193 s.
# Temps de suppression de 75000 données sur la 1ère table: 537.22333384 s.
# Temps de suppression de 75000 données sur la 2ème table:  375.09532809 s.
#
#
# ##################################################
# OPERATIONS SUR 100000 DONNEES
# ##################################################
#
#
# Temps de connexion à la base de données redis:
# 0.00026297569274902344 secondes.
# Temps de connexion à la base de données sqlite:
# 0.0003960132598876953 secondes.
# Temps d'insertion de 100000 données sur une base de données préremplies 1000 données sur Redis:             0.42793012 s.
# Temps de récupération de 100000 données sur une base de données préremplies 1000 données sur Redis:             0.43797302 s.
# Temps de modification de 100000 données sur une base de données préremplies 1000 données sur Redis:             0.41623211 s.
# Temps de suppression de 100000 données sur une base de données préremplies 1000 données sur Redis:             0.19983697 s.
# Temps d'insertion de 100000 données sur une base de données préremplies 1000 données sur SQLite:             351.55168200 s.
# Temps d'insertion de 100000 données sur la 1ère table: 175.89060187 s.
# Temps d'insertion de 100000 données sur la 2ème table:  175.66108012 s.
# Temps de récupération en moyenne sur 1000 données sur SQLite:            1555.51030254 s.
# Temps de modification de 100000 données sur une base de données préremplies 1000 données sur SQLite:             2432.63374209 s.
# Temps de modification de 100000 données sur la 1ère table: 1330.06299591 s.
# Temps de modification de 100000 données sur la 2ème table:  1102.57074618 s.
# Temps de suppression de 100000 données sur une base de données préremplies 1000 données sur SQLite:             1142.37517405 s.
# Temps de suppression de 100000 données sur la 1ère table: 685.13499093 s.
# Temps de suppression de 100000 données sur la 2ème table:  457.24018312 s.

# %%
data_redis = {
    'nb_data': list_nb_data,
    'Insertion': redis_insert,
    'Selection': redis_retrieval,
    'Mise a jour': redis_update,
    'Suppression': redis_delete
}

df_redis = pd.DataFrame(data=data_redis)
fig = go.Figure()

fig.add_trace(go.Scatter(x=df_redis['nb_data'], y=df_redis['Insertion'],
                         line=dict(color='blue'), mode='lines', name='Insertion'))

fig.add_trace(go.Scatter(x=df_redis['nb_data'], y=df_redis['Suppression'],
                         line=dict(color='red'), mode='lines', name='Suppression'))

fig.add_trace(go.Scatter(x=df_redis['nb_data'], y=df_redis['Mise a jour'],
                         line=dict(color='green'), mode='lines', name='Mise a jour'))

fig.add_trace(go.Scatter(x=df_redis['nb_data'], y=df_redis['Selection'],
                         line=dict(color='purple'), mode='lines', name='Récupération'))

fig.update_layout(
    title='Performance evolution with redis',
    xaxis_title='nb_data',
    yaxis_title='Values',
)


pio.write_html(fig, file='graph_redis_v2.html', auto_open=True)

# %%
data_sqlite = {
    'nb_data': list_nb_data,
    'Insertion': sqlite_insert, 
    'Selection': sqlite_retrieval, 
    'Mise a jour': sqlite_update, 
    'Suppression': sqlite_delete
}


df_sqlite = pd.DataFrame(data=data_sqlite)
fig = go.Figure()

fig.add_trace(go.Scatter(x=df_sqlite['nb_data'], y=df_sqlite['Insertion'],
                         line=dict(color='blue'), mode='lines', name='Insertion'))

fig.add_trace(go.Scatter(x=df_sqlite['nb_data'], y=df_sqlite['Suppression'],
                         line=dict(color='red'), mode='lines', name='Suppression'))

fig.add_trace(go.Scatter(x=df_sqlite['nb_data'], y=df_sqlite['Mise a jour'],
                         line=dict(color='green'), mode='lines', name='Mise a jour'))

fig.add_trace(go.Scatter(x=df_sqlite['nb_data'], y=df_sqlite['Selection'],
                         line=dict(color='purple'), mode='lines', name='Récupération'))

fig.update_layout(
    title='Performance evolution with SQLite',
    xaxis_title='nb_data',
    yaxis_title='Values',
)

pio.write_html(fig, file='graph_sqlite_v2.html', auto_open=True)
